# %%
from bs4 import BeautifulSoup
import urllib.request
from selenium import webdriver
from selenium.common.exceptions import ElementNotInteractableException
import os
import socket

timeout = 20
socket.setdefaulttimeout(timeout)

driver = webdriver.Chrome('./chromedriver')
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

# %%
def download_manga(url = ''):
    driver.get(url)
    while(True):
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        title = soup.find('meta', attrs={'name': 'title'})
        title = title.get('content')
        try:
            os.mkdir('./' + title)
        except FileExistsError:
            pass

        tag = soup.find('div', attrs={'class': 'view-content scroll-viewer'})
        images = tag.find_all('img')
        print(title + ' '+ str(len(images)) + '장')
        for i, img in enumerate(images):
            img_src = img.get('src')
            
            loop = 5
            while(loop > 0):
                try:
                    urllib.request.urlretrieve(img_src, './' + title + '/' + str(i) + '.jpg')
                except Exception as e:
                    print(e)
                    loop -= 1
                    continue
                else:
                    break
        
        try:
            driver.find_element_by_xpath('//a[@class="chapter_next"]').click()
        except ElementNotInteractableException:
            break
        except Exception as e:
            print(e)
    
    print("done")

# %%
download_manga(input())
# Out:
# https://manamoa26.net/bbs/board.php?bo_table=manga&wr_id=805487
# 어떤 과학의 초전자포 113화 0장
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1439cb0e6b39> in <module>
# ----> 1 download_manga(input())
#
# <ipython-input-2-a05f77f235a9> in download_manga(url)
#      30
#      31         try:
# ---> 32             driver.find_element_by_xpath('//a[@class="chapter_next"]').click()
#      33         except ElementNotInteractableException:
#      34             break
#
# C:\Users\chsrl\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ...

# %%
img_list = ["https://filecdn.xyz/upload/v1/958259932a5fdbf2fa49a084e97aea72.jpg","https:\/\/filecdn.xyz\/upload\/v1\/b5b9dcf75cf5b86242c75ef732b4f2df.jpg","https:\/\/filecdn.xyz\/upload\/v1\/dc7d9be1566a21d0ca4c7de1ed582ea5.jpg","https:\/\/filecdn.xyz\/upload\/v1\/08f68503a036e4cacb0bc45081bee0e6.jpg","https:\/\/filecdn.xyz\/upload\/v1\/8a78a17d2ebf05ad3a951ad66104c416.jpg","https:\/\/filecdn.xyz\/upload\/v1\/ef0213e2bcd83045fb05cee043093617.jpg","https:\/\/filecdn.xyz\/upload\/v1\/ce7b7da40256d7e59ef9f66853d7a31d.jpg","https:\/\/filecdn.xyz\/upload\/v1\/5acc9192424ae229b6596edc2eed7877.jpg","https:\/\/filecdn.xyz\/upload\/v1\/409f1c6d0054836593dca97d2c94eb53.jpg","https:\/\/filecdn.xyz\/upload\/v1\/228d6817260430682d77be1f414790dc.jpg","https:\/\/filecdn.xyz\/upload\/v1\/ccc64c6559bfc1cb28de30359fbde7b1.jpg","https:\/\/filecdn.xyz\/upload\/v1\/6831186ba2f75c460f0681090a859039.jpg","https:\/\/filecdn.xyz\/upload\/v1\/1881fbea7b9581b3b196bea7d076f4fc.jpg","https:\/\/filecdn.xyz\/upload\/v1\/d887155bcb19167efb9f6ceb0438e45d.jpg","https:\/\/filecdn.xyz\/upload\/v1\/7143a805d402d42e0b5cf5183422092c.jpg","https:\/\/filecdn.xyz\/upload\/v1\/7553c3bc316cb38d497e5c389a52b7cb.jpg","https:\/\/filecdn.xyz\/upload\/v1\/fa265c96070963af7713186d3d29f71f.jpg","https:\/\/filecdn.xyz\/upload\/v1\/cd066be9f4a71ca3a2eaeb6fc5f4f199.jpg","https:\/\/filecdn.xyz\/upload\/v1\/84b8c5013767844313cd0509f209c213.jpg","https:\/\/filecdn.xyz\/upload\/v1\/5a6a61c1dd575a777c3d431f1946f32d.jpg","https:\/\/filecdn.xyz\/upload\/v1\/0fec3e9b5d4fce3df0a3fd6c2277af7c.jpg","https:\/\/filecdn.xyz\/upload\/v1\/84f8b3bd20eb7578e578f984b5c2906b.jpg","https:\/\/filecdn.xyz\/upload\/v1\/5226716d8c21cc3b1597908f65ad96f7.jpg","https:\/\/filecdn.xyz\/upload\/v1\/8a9ea54b377e8dbf6cb03c0f3dc1e0f1.jpg"]
for i, img in enumerate(img_list):

        loop = 5
        while(loop > 0):
            try:
                urllib.request.urlretrieve(img, './어떤 과학의 초전자포 113화/' + str(i) + '.jpg')
            except Exception as e:
                print(e)
                loop -= 1
                continue
            else:
                break
# Out:
# <urlopen error [Errno 11002] getaddrinfo failed>
# <urlopen error [Errno 11002] getaddrinfo failed>
# <urlopen error [Errno 11002] getaddrinfo failed>
# <urlopen error [Errno 11002] getaddrinfo failed>
# <urlopen error [Errno 11002] getaddrinfo failed>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# <urlopen error no host given>
# ...
